# %%
import pandas as pd
import numpy as np

# %%
X_train=pd.read_csv('X_train.csv')
X_test=pd.read_csv('X_test.csv')
y_train=pd.read_csv('y_train.csv')
y_test=pd.read_csv('y_test.csv')

# %%
X_test
# Out:
#          Age       Sex       BMI        BP        S1        S2        S3  \
# 0   0.067136 -0.044642  0.003494  0.035644  0.049341  0.031254  0.070730
# 1  -0.078165  0.050680  0.077863  0.052858  0.078236  0.064447  0.026550
# 2   0.041708  0.050680 -0.014828 -0.017135 -0.005697  0.008394 -0.013948
# 3  -0.045472 -0.044642 -0.048241 -0.019442 -0.000193 -0.016032  0.067048
# 4   0.009016  0.050680  0.069241  0.059744  0.017694 -0.023234 -0.047082
# ..       ...       ...       ...       ...       ...       ...       ...
# 84  0.009016 -0.044642  0.016428  0.004658  0.009439  0.010586 -0.028674
# 85 -0.052738 -0.044642  0.071397 -0.074527 -0.015328 -0.001314  0.004460
# 86  0.030811 -0.044642  0.104809  0.076958 -0.011201 -0.011335 -0.058127
# 87  0.023546 -0.044642  0.070319  0.025315 -0.034592 -0.014466 -0.032356
# 88  0.056239  0.050680 -0.030996  0.008101  0.019070  0.021233  0.033914
#
#           S4        S5        S6
# 0  -0.039493 -0.000612  0.019633
# 1  -0.002592  0.040673 -0.009362
# 2  -0.001854 -0.011897  0.003064
# 3  -0.039493 -0.024795  0.019633
# 4   0.034309  0.103297  0.073480
# ..       ...       ...       ...
# 84  0.034309  0.038968  0.119043
# 85 -0.021412 -0.046883  0.003064
# 86  0.034309  0.057108  0.036201
# 87 -0.002592 -0.019198 -0.009362
# 88 -0.039493 -0.029526 -0.059067
#
# [89 rows x 10 columns]

# %%
class MultipleLR:
    def __init__(self):
        self.coef_=None
        self.intercept_=None
    def fit(self,X_train,y_train):
      #add 1 to X Matrix
        X_train=np.insert(X_train,0,1,axis=1)
      # Calculate coeffs
        betas=np.linalg.inv(np.dot(X_train.T,X_train)).dot(X_train.T).dot(y_train)
      # Separate Intercept and Coeffs
        self.intercept_=betas[0]
        self.coef_=betas[1:]
        print("Intercept: ", self.intercept_)
        print("Coeffs: ", self.coef_)
    def predict(self, X_test):
        y_pred=np.dot(X_test,self.coef_)+self.intercept_
        return y_pred

# %%
Model=MultipleLR()

# %%
Model.fit(X_train,y_train)
# Out:
# Intercept:  [151.88331005]
# Coeffs:  [[  -9.15865318]
#  [-205.45432163]
#  [ 516.69374454]
#  [ 340.61999905]
#  [-895.5520019 ]
#  [ 561.22067904]
#  [ 153.89310954]
#  [ 126.73139688]
#  [ 861.12700152]
#  [  52.42112238]]

# %%
y_pred=Model.predict(X_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.43993386615689656
